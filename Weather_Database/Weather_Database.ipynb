# %%
# Import Dependencies
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import time
from datetime import datetime
import requests

# %%
# Set up API Key and URL
from config import weather_api_key
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combos

lats = np.random.uniform(-90.000, 90.000, size=2000)
lngs = np.random.uniform(-180.000, 180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 740

# %%
# Create a list to hold weather data

city_data = []

# Print beginning of the logging

print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all cities in the list
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 to prevent timeouts.
    if(i % 50 == 0 and i >=50):
        set_count += 1
        record_count = 1
        time.sleep(60)
        
    # Create endpoint URL for each city
    city_url = url + "&q=" + city.replace(' ','+')
    
    # Log URL, record, set numbers, and city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to record count
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        description = city_weather['weather'][0]['description']
        
#         # Convert the date to ISO standard.
#         city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | kralendijk
# Processing Record 2 of Set 1 | buchanan
# Processing Record 3 of Set 1 | bluff
# Processing Record 4 of Set 1 | kapaa
# Processing Record 5 of Set 1 | haines junction
# Processing Record 6 of Set 1 | port blair
# Processing Record 7 of Set 1 | mar del plata
# Processing Record 8 of Set 1 | bethel
# Processing Record 9 of Set 1 | ponta do sol
# Processing Record 10 of Set 1 | hithadhoo
# Processing Record 11 of Set 1 | ribeira grande
# Processing Record 12 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 13 of Set 1 | albany
# Processing Record 14 of Set 1 | mujiayingzi
# Processing Record 15 of Set 1 | oshkosh
# Processing Record 16 of Set 1 | barrow
# Processing Record 17 of Set 1 | honiara
# Processing Record 18 of Set 1 | bredasdorp
# Processing Record 19 of Set 1 | snezhnogorsk
# Processing Record 20 of Set 1 | mount isa
# Processing Record 21 of Set 1 | bernburg
# Processing Record 22 of Set 1 | cherskiy
# Processing Record 23 of Set 1 | kavieng
# Processing Record 24 of Set 1 | tiksi
# Processing Record 25 of Set 1 | anaconda
# Processing Record 26 of Set 1 | harnosand
# Processing Record 27 of Set 1 | hermanus
# Processing Record 28 of Set 1 | saint-philippe
# Processing Record 29 of Set 1 | hobart
# Processing Record 30 of Set 1 | bengkulu
# Processing Record 31 of Set 1 | hasaki
# Processing Record 32 of Set 1 | cabras
# Processing Record 33 of Set 1 | norman wells
# Processing Record 34 of Set 1 | ushuaia
# Processing Record 35 of Set 1 | north bend
# Processing Record 36 of Set 1 | constitucion
# Processing Record 37 of Set 1 | dwarka
# Processing Record 38 of Set 1 | souillac
# Processing Record 39 of Set 1 | lubao
# Processing Record 40 of Set 1 | mitzic
# Processing Record 41 of Set 1 | gamba
# Processing Record 42 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 43 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 44 of Set 1 | punta arenas
# Processing Record 45 of Set 1 | nouakchott
# Processing Record 46 of Set 1 | tashtyp
# Processing Record 47 of Set 1 | san patricio
# Processing Record 48 of Set 1 | santa isabel
# Processing Record 49 of Set 1 | thinadhoo
# Processing Record 50 of Set 1 | inuvik
# Processing Record 1 of Set 2 | kachug
# Processing Record 2 of Set 2 | adrar
# Processing Record 3 of Set 2 | new norfolk
# Processing Record 4 of Set 2 | cape town
# Processing Record 5 of Set 2 | carnarvon
# Processing Record 6 of Set 2 | tayu
# Processing Record 7 of Set 2 | bayanday
# Processing Record 8 of Set 2 | tsuyama
# Processing Record 9 of Set 2 | horsham
# Processing Record 10 of Set 2 | roberto payan
# City not found. Skipping...
# Processing Record 11 of Set 2 | qaanaaq
# Processing Record 12 of Set 2 | donji milanovac
# Processing Record 13 of Set 2 | east london
# Processing Record 14 of Set 2 | todos santos
# Processing Record 15 of Set 2 | badarpur
# Processing Record 16 of Set 2 | avera
# Processing Record 17 of Set 2 | kruisfontein
# Processing Record 18 of Set 2 | champerico
# Processing Record 19 of Set 2 | rikitea
# Processing Record 20 of Set 2 | altus
# Processing Record 21 of Set 2 | namatanai
# Processing Record 22 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 23 of Set 2 | torbay
# Processing Record 24 of Set 2 | prince rupert
# Processing Record 25 of Set 2 | bolungarvik
# City not found. Skipping...
# Processing Record 26 of Set 2 | saint anthony
# Processing Record 27 of Set 2 | saint-honore
# Processing Record 28 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 29 of Set 2 | avarua
# Processing Record 30 of Set 2 | vardo
# Processing Record 31 of Set 2 | imbituba
# Processing Record 32 of Set 2 | butaritari
# Processing Record 33 of Set 2 | kieta
# Processing Record 34 of Set 2 | lompoc
# Processing Record 35 of Set 2 | santa fe
# Processing Record 36 of Set 2 | tartagal
# Processing Record 37 of Set 2 | grand gaube
# Processing Record 38 of Set 2 | pevek
# Processing Record 39 of Set 2 | kigorobya
# Processing Record 40 of Set 2 | berezovyy
# Processing Record 41 of Set 2 | dikson
# Processing Record 42 of Set 2 | provideniya
# Processing Record 43 of Set 2 | talnakh
# Processing Record 44 of Set 2 | saskylakh
# Processing Record 45 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 46 of Set 2 | severo-kurilsk
# Processing Record 47 of Set 2 | nam tha
# City not found. Skipping...
# Processing Record 48 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 49 of Set 2 | atuona
# Processing Record 50 of Set 2 | kodinsk
# Processing Record 1 of Set 3 | port alfred
# Processing Record 2 of Set 3 | kavaratti
# Processing Record 3 of Set 3 | ucluelet
# Processing Record 4 of Set 3 | vaini
# Processing Record 5 of Set 3 | yellowknife
# Processing Record 6 of Set 3 | flinders
# Processing Record 7 of Set 3 | kaeo
# Processing Record 8 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 9 of Set 3 | toliary
# City not found. Skipping...
# Processing Record 10 of Set 3 | ambulu
# Processing Record 11 of Set 3 | georgetown
# Processing Record 12 of Set 3 | yumen
# Processing Record 13 of Set 3 | jiddah
# City not found. Skipping...
# Processing Record 14 of Set 3 | mataura
# Processing Record 15 of Set 3 | port elizabeth
# Processing Record 16 of Set 3 | airai
# Processing Record 17 of Set 3 | manicore
# Processing Record 18 of Set 3 | faanui
# Processing Record 19 of Set 3 | castro
# Processing Record 20 of Set 3 | madang
# Processing Record 21 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 22 of Set 3 | waipawa
# Processing Record 23 of Set 3 | hobyo
# Processing Record 24 of Set 3 | puerto ayora
# Processing Record 25 of Set 3 | nacala
# Processing Record 26 of Set 3 | saint george
# Processing Record 27 of Set 3 | gubkinskiy
# Processing Record 28 of Set 3 | karratha
# Processing Record 29 of Set 3 | ust-nera
# Processing Record 30 of Set 3 | te anau
# Processing Record 31 of Set 3 | pangai
# Processing Record 32 of Set 3 | codrington
# Processing Record 33 of Set 3 | busselton
# Processing Record 34 of Set 3 | lebu
# Processing Record 35 of Set 3 | kodiak
# Processing Record 36 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 37 of Set 3 | thompson
# Processing Record 38 of Set 3 | kurchum
# Processing Record 39 of Set 3 | arlit
# Processing Record 40 of Set 3 | canon city
# Processing Record 41 of Set 3 | port lincoln
# Processing Record 42 of Set 3 | luba
# Processing Record 43 of Set 3 | tuktoyaktuk
# Processing Record 44 of Set 3 | saint-augustin
# Processing Record 45 of Set 3 | arraial do cabo
# Processing Record 46 of Set 3 | nelson bay
# Processing Record 47 of Set 3 | huarmey
# Processing Record 48 of Set 3 | boa vista
# Processing Record 49 of Set 3 | baghdad
# Processing Record 50 of Set 3 | alofi
# Processing Record 1 of Set 4 | jamestown
# Processing Record 2 of Set 4 | bathsheba
# Processing Record 3 of Set 4 | san cristobal
# Processing Record 4 of Set 4 | vanavara
# Processing Record 5 of Set 4 | platteville
# Processing Record 6 of Set 4 | mahebourg
# Processing Record 7 of Set 4 | avila
# Processing Record 8 of Set 4 | bambous virieux
# Processing Record 9 of Set 4 | fort nelson
# Processing Record 10 of Set 4 | saint-joseph
# Processing Record 11 of Set 4 | muros
# Processing Record 12 of Set 4 | kibaya
# Processing Record 13 of Set 4 | pisco
# Processing Record 14 of Set 4 | burnie
# Processing Record 15 of Set 4 | cururupu
# Processing Record 16 of Set 4 | artyk
# City not found. Skipping...
# Processing Record 17 of Set 4 | mendeleyevo
# Processing Record 18 of Set 4 | bargal
# City not found. Skipping...
# Processing Record 19 of Set 4 | santa isabel do rio negro
# Processing Record 20 of Set 4 | victoria
# Processing Record 21 of Set 4 | khatanga
# Processing Record 22 of Set 4 | mpulungu
# Processing Record 23 of Set 4 | kaitangata
# Processing Record 24 of Set 4 | upernavik
# Processing Record 25 of Set 4 | esperance
# Processing Record 26 of Set 4 | sulangan
# Processing Record 27 of Set 4 | saldanha
# Processing Record 28 of Set 4 | cayenne
# Processing Record 29 of Set 4 | north myrtle beach
# Processing Record 30 of Set 4 | malindi
# Processing Record 31 of Set 4 | wanlaweyn
# Processing Record 32 of Set 4 | oistins
# Processing Record 33 of Set 4 | nova vicosa
# Processing Record 34 of Set 4 | ancud
# Processing Record 35 of Set 4 | redlands
# Processing Record 36 of Set 4 | vestmannaeyjar
# Processing Record 37 of Set 4 | hilo
# Processing Record 38 of Set 4 | nkayi
# Processing Record 39 of Set 4 | nantucket
# Processing Record 40 of Set 4 | soe
# Processing Record 41 of Set 4 | rantauprapat
# Processing Record 42 of Set 4 | carutapera
# Processing Record 43 of Set 4 | kloulklubed
# Processing Record 44 of Set 4 | kahului
# Processing Record 45 of Set 4 | gornoye loo
# Processing Record 46 of Set 4 | price
# Processing Record 47 of Set 4 | taebla
# Processing Record 48 of Set 4 | nampula
# Processing Record 49 of Set 4 | calvinia
# Processing Record 50 of Set 4 | amapa
# Processing Record 1 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 2 of Set 5 | cockburn harbour
# City not found. Skipping...
# Processing Record 3 of Set 5 | williams lake
# Processing Record 4 of Set 5 | benguela
# Processing Record 5 of Set 5 | ostrovnoy
# Processing Record 6 of Set 5 | nishihara
# Processing Record 7 of Set 5 | sao joao da barra
# Processing Record 8 of Set 5 | coquimbo
# Processing Record 9 of Set 5 | portland
# Processing Record 10 of Set 5 | iquitos
# Processing Record 11 of Set 5 | tallahassee
# Processing Record 12 of Set 5 | savannah bight
# Processing Record 13 of Set 5 | sao felix do xingu
# Processing Record 14 of Set 5 | marienburg
# Processing Record 15 of Set 5 | omsukchan
# Processing Record 16 of Set 5 | iguape
# Processing Record 17 of Set 5 | olga
# Processing Record 18 of Set 5 | coahuayana
# Processing Record 19 of Set 5 | salalah
# Processing Record 20 of Set 5 | chokurdakh
# Processing Record 21 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 22 of Set 5 | awjilah
# Processing Record 23 of Set 5 | cap malheureux
# Processing Record 24 of Set 5 | beaverton
# Processing Record 25 of Set 5 | ossora
# Processing Record 26 of Set 5 | bacuit
# City not found. Skipping...
# Processing Record 27 of Set 5 | luckenwalde
# Processing Record 28 of Set 5 | barawe
# City not found. Skipping...
# Processing Record 29 of Set 5 | taoudenni
# Processing Record 30 of Set 5 | caravelas
# Processing Record 31 of Set 5 | agirish
# Processing Record 32 of Set 5 | nikolskoye
# Processing Record 33 of Set 5 | vitim
# Processing Record 34 of Set 5 | clyde river
# Processing Record 35 of Set 5 | dale
# Processing Record 36 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 37 of Set 5 | canico
# Processing Record 38 of Set 5 | strezhevoy
# Processing Record 39 of Set 5 | bahia de caraquez
# Processing Record 40 of Set 5 | tasiilaq
# Processing Record 41 of Set 5 | ostroda
# Processing Record 42 of Set 5 | sao jose da coroa grande
# Processing Record 43 of Set 5 | puerto escondido
# Processing Record 44 of Set 5 | parainen
# Processing Record 45 of Set 5 | changji
# Processing Record 46 of Set 5 | ishigaki
# Processing Record 47 of Set 5 | pipri
# Processing Record 48 of Set 5 | sitka
# Processing Record 49 of Set 5 | killorglin
# Processing Record 50 of Set 5 | viterbo
# Processing Record 1 of Set 6 | alugan
# Processing Record 2 of Set 6 | fairbanks
# Processing Record 3 of Set 6 | port shepstone
# Processing Record 4 of Set 6 | makrana
# Processing Record 5 of Set 6 | birjand
# Processing Record 6 of Set 6 | barcelona
# Processing Record 7 of Set 6 | asau
# Processing Record 8 of Set 6 | bria
# Processing Record 9 of Set 6 | grindavik
# Processing Record 10 of Set 6 | dingle
# Processing Record 11 of Set 6 | satitoa
# City not found. Skipping...
# Processing Record 12 of Set 6 | luderitz
# Processing Record 13 of Set 6 | oleksandrivka
# Processing Record 14 of Set 6 | juegang
# Processing Record 15 of Set 6 | longyearbyen
# Processing Record 16 of Set 6 | pizarro
# Processing Record 17 of Set 6 | labuhan
# Processing Record 18 of Set 6 | haibowan
# City not found. Skipping...
# Processing Record 19 of Set 6 | luang prabang
# Processing Record 20 of Set 6 | bonthe
# Processing Record 21 of Set 6 | velesin
# Processing Record 22 of Set 6 | ambon
# Processing Record 23 of Set 6 | tuy hoa
# Processing Record 24 of Set 6 | vostok
# Processing Record 25 of Set 6 | okha
# Processing Record 26 of Set 6 | ponta delgada
# Processing Record 27 of Set 6 | moerai
# Processing Record 28 of Set 6 | matagami
# Processing Record 29 of Set 6 | namibe
# Processing Record 30 of Set 6 | chuy
# Processing Record 31 of Set 6 | lavrentiya
# Processing Record 32 of Set 6 | iqaluit
# Processing Record 33 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 34 of Set 6 | comodoro rivadavia
# Processing Record 35 of Set 6 | piney green
# Processing Record 36 of Set 6 | barstow
# Processing Record 37 of Set 6 | middletown
# Processing Record 38 of Set 6 | torbat-e jam
# Processing Record 39 of Set 6 | mildura
# Processing Record 40 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 41 of Set 6 | hay river
# Processing Record 42 of Set 6 | praia
# Processing Record 43 of Set 6 | deputatskiy
# Processing Record 44 of Set 6 | romny
# Processing Record 45 of Set 6 | shakhovskaya
# Processing Record 46 of Set 6 | aasiaat
# Processing Record 47 of Set 6 | isangel
# Processing Record 48 of Set 6 | manakara
# Processing Record 49 of Set 6 | mrirt
# City not found. Skipping...
# Processing Record 50 of Set 6 | angoche
# Processing Record 1 of Set 7 | richards bay
# Processing Record 2 of Set 7 | sindor
# Processing Record 3 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 4 of Set 7 | miri
# Processing Record 5 of Set 7 | zhanaozen
# Processing Record 6 of Set 7 | ust-karsk
# Processing Record 7 of Set 7 | belyy yar
# Processing Record 8 of Set 7 | baykit
# Processing Record 9 of Set 7 | beringovskiy
# Processing Record 10 of Set 7 | meulaboh
# Processing Record 11 of Set 7 | geraldton
# Processing Record 12 of Set 7 | hofn
# Processing Record 13 of Set 7 | yungho
# City not found. Skipping...
# Processing Record 14 of Set 7 | cabo san lucas
# Processing Record 15 of Set 7 | bongaree
# Processing Record 16 of Set 7 | torrington
# Processing Record 17 of Set 7 | san carlos
# Processing Record 18 of Set 7 | tilichiki
# Processing Record 19 of Set 7 | aykhal
# Processing Record 20 of Set 7 | nhulunbuy
# Processing Record 21 of Set 7 | touros
# Processing Record 22 of Set 7 | naze
# Processing Record 23 of Set 7 | lasa
# Processing Record 24 of Set 7 | taltal
# Processing Record 25 of Set 7 | najran
# Processing Record 26 of Set 7 | changping
# Processing Record 27 of Set 7 | alice springs
# Processing Record 28 of Set 7 | kinna
# Processing Record 29 of Set 7 | abu kamal
# Processing Record 30 of Set 7 | saint-georges
# Processing Record 31 of Set 7 | koungou
# Processing Record 32 of Set 7 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 33 of Set 7 | sola
# Processing Record 34 of Set 7 | acapulco
# Processing Record 35 of Set 7 | yaan
# Processing Record 36 of Set 7 | arenal
# Processing Record 37 of Set 7 | coihaique
# Processing Record 38 of Set 7 | wajima
# Processing Record 39 of Set 7 | jambi
# Processing Record 40 of Set 7 | fare
# Processing Record 41 of Set 7 | labuan
# Processing Record 42 of Set 7 | auki
# Processing Record 43 of Set 7 | beni
# Processing Record 44 of Set 7 | caconda
# Processing Record 45 of Set 7 | betong
# Processing Record 46 of Set 7 | sergeyevka
# Processing Record 47 of Set 7 | morant bay
# Processing Record 48 of Set 7 | banda aceh
# Processing Record 49 of Set 7 | sibolga
# Processing Record 50 of Set 7 | catuday
# Processing Record 1 of Set 8 | balgazyn
# Processing Record 2 of Set 8 | kupang
# Processing Record 3 of Set 8 | fortuna
# Processing Record 4 of Set 8 | lovozero
# Processing Record 5 of Set 8 | panlaitan
# Processing Record 6 of Set 8 | nanortalik
# Processing Record 7 of Set 8 | hamilton
# Processing Record 8 of Set 8 | henties bay
# Processing Record 9 of Set 8 | port moresby
# Processing Record 10 of Set 8 | yuzhnyy
# Processing Record 11 of Set 8 | derzhavinsk
# Processing Record 12 of Set 8 | cienfuegos
# Processing Record 13 of Set 8 | bourail
# Processing Record 14 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 15 of Set 8 | faya
# Processing Record 16 of Set 8 | sao gabriel da cachoeira
# Processing Record 17 of Set 8 | maneadero
# Processing Record 18 of Set 8 | dailly
# Processing Record 19 of Set 8 | west bay
# Processing Record 20 of Set 8 | poum
# Processing Record 21 of Set 8 | tshela
# Processing Record 22 of Set 8 | katangli
# Processing Record 23 of Set 8 | besikduzu
# Processing Record 24 of Set 8 | mudyuga
# City not found. Skipping...
# Processing Record 25 of Set 8 | douglas
# Processing Record 26 of Set 8 | les cayes
# Processing Record 27 of Set 8 | esso
# Processing Record 28 of Set 8 | sao filipe
# Processing Record 29 of Set 8 | christchurch
# Processing Record 30 of Set 8 | mafinga
# Processing Record 31 of Set 8 | husavik
# Processing Record 32 of Set 8 | cabedelo
# Processing Record 33 of Set 8 | serpa
# Processing Record 34 of Set 8 | jurm
# Processing Record 35 of Set 8 | vianen
# Processing Record 36 of Set 8 | pastavy
# Processing Record 37 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 38 of Set 8 | pudozh
# Processing Record 39 of Set 8 | linden
# Processing Record 40 of Set 8 | abonnema
# Processing Record 41 of Set 8 | kamenka
# Processing Record 42 of Set 8 | pandan
# Processing Record 43 of Set 8 | leningradskiy
# Processing Record 44 of Set 8 | itoman
# Processing Record 45 of Set 8 | ekpoma
# Processing Record 46 of Set 8 | baruun-urt
# Processing Record 47 of Set 8 | harsud
# Processing Record 48 of Set 8 | bilibino
# Processing Record 49 of Set 8 | talcahuano
# Processing Record 50 of Set 8 | aldergrove
# Processing Record 1 of Set 9 | harper
# Processing Record 2 of Set 9 | sassandra
# Processing Record 3 of Set 9 | griffith
# Processing Record 4 of Set 9 | miramar
# Processing Record 5 of Set 9 | guerrero negro
# Processing Record 6 of Set 9 | thunder bay
# Processing Record 7 of Set 9 | kenora
# Processing Record 8 of Set 9 | kerman
# Processing Record 9 of Set 9 | cervo
# Processing Record 10 of Set 9 | stromness
# Processing Record 11 of Set 9 | bunschoten
# Processing Record 12 of Set 9 | kabo
# Processing Record 13 of Set 9 | bairnsdale
# Processing Record 14 of Set 9 | high level
# Processing Record 15 of Set 9 | karkaralinsk
# City not found. Skipping...
# Processing Record 16 of Set 9 | wairoa
# Processing Record 17 of Set 9 | bowen
# Processing Record 18 of Set 9 | liling
# Processing Record 19 of Set 9 | omboue
# Processing Record 20 of Set 9 | sant julia de loria
# Processing Record 21 of Set 9 | dunedin
# Processing Record 22 of Set 9 | orbetello
# Processing Record 23 of Set 9 | axim
# Processing Record 24 of Set 9 | mount gambier
# Processing Record 25 of Set 9 | marsa matruh
# Processing Record 26 of Set 9 | berlevag
# Processing Record 27 of Set 9 | temaraia
# City not found. Skipping...
# Processing Record 28 of Set 9 | matara
# Processing Record 29 of Set 9 | macomer
# Processing Record 30 of Set 9 | victor harbor
# Processing Record 31 of Set 9 | inderborskiy
# City not found. Skipping...
# Processing Record 32 of Set 9 | sur
# Processing Record 33 of Set 9 | a
# City not found. Skipping...
# Processing Record 34 of Set 9 | felidhoo
# City not found. Skipping...
# Processing Record 35 of Set 9 | severodvinsk
# Processing Record 36 of Set 9 | casper
# Processing Record 37 of Set 9 | rantepao
# Processing Record 38 of Set 9 | languyan
# Processing Record 39 of Set 9 | solnechnyy
# Processing Record 40 of Set 9 | tuatapere
# Processing Record 41 of Set 9 | the valley
# Processing Record 42 of Set 9 | plouzane
# Processing Record 43 of Set 9 | lorengau
# Processing Record 44 of Set 9 | kaabong
# Processing Record 45 of Set 9 | cottonwood
# Processing Record 46 of Set 9 | pangnirtung
# Processing Record 47 of Set 9 | urucara
# Processing Record 48 of Set 9 | delta del tigre
# Processing Record 49 of Set 9 | kawana waters
# City not found. Skipping...
# Processing Record 50 of Set 9 | kambove
# Processing Record 1 of Set 10 | palm beach
# Processing Record 2 of Set 10 | santa cruz de tenerife
# Processing Record 3 of Set 10 | valparaiso
# Processing Record 4 of Set 10 | camacha
# Processing Record 5 of Set 10 | newport
# Processing Record 6 of Set 10 | katsuura
# Processing Record 7 of Set 10 | bereda
# Processing Record 8 of Set 10 | padang
# Processing Record 9 of Set 10 | raga
# Processing Record 10 of Set 10 | anzio
# Processing Record 11 of Set 10 | malakal
# Processing Record 12 of Set 10 | vila franca do campo
# Processing Record 13 of Set 10 | fethiye
# Processing Record 14 of Set 10 | karpenision
# City not found. Skipping...
# Processing Record 15 of Set 10 | dulangan
# Processing Record 16 of Set 10 | sinnamary
# Processing Record 17 of Set 10 | buraydah
# Processing Record 18 of Set 10 | payyannur
# Processing Record 19 of Set 10 | nesbyen
# Processing Record 20 of Set 10 | praia da vitoria
# Processing Record 21 of Set 10 | susanville
# Processing Record 22 of Set 10 | kalemie
# Processing Record 23 of Set 10 | darhan
# Processing Record 24 of Set 10 | plymouth
# Processing Record 25 of Set 10 | jalu
# Processing Record 26 of Set 10 | walvis bay
# Processing Record 27 of Set 10 | paamiut
# Processing Record 28 of Set 10 | yulara
# Processing Record 29 of Set 10 | ayios matthaios
# City not found. Skipping...
# Processing Record 30 of Set 10 | tando adam
# Processing Record 31 of Set 10 | kovdor
# Processing Record 32 of Set 10 | balabac
# Processing Record 33 of Set 10 | nome
# Processing Record 34 of Set 10 | kousseri
# Processing Record 35 of Set 10 | egvekinot
# Processing Record 36 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 37 of Set 10 | banff
# Processing Record 38 of Set 10 | samarai
# Processing Record 39 of Set 10 | mehamn
# Processing Record 40 of Set 10 | monte alegre
# Processing Record 41 of Set 10 | bolshoye sorokino
# City not found. Skipping...
# Processing Record 42 of Set 10 | tombouctou
# Processing Record 43 of Set 10 | termoli
# Processing Record 44 of Set 10 | cheremukhovo
# Processing Record 45 of Set 10 | plettenberg bay
# Processing Record 46 of Set 10 | alpatovo
# Processing Record 47 of Set 10 | black river
# Processing Record 48 of Set 10 | antofagasta
# Processing Record 49 of Set 10 | igarka
# Processing Record 50 of Set 10 | gigmoto
# Processing Record 1 of Set 11 | tongliao
# Processing Record 2 of Set 11 | noumea
# Processing Record 3 of Set 11 | el vigia
# Processing Record 4 of Set 11 | rio grande
# Processing Record 5 of Set 11 | jinka
# Processing Record 6 of Set 11 | ilam
# Processing Record 7 of Set 11 | skalistyy
# City not found. Skipping...
# Processing Record 8 of Set 11 | kegayli
# City not found. Skipping...
# Processing Record 9 of Set 11 | ovre ardal
# Processing Record 10 of Set 11 | phan rang
# City not found. Skipping...
# Processing Record 11 of Set 11 | batman
# Processing Record 12 of Set 11 | florianopolis
# Processing Record 13 of Set 11 | cosina
# Processing Record 14 of Set 11 | tefe
# Processing Record 15 of Set 11 | ouadda
# Processing Record 16 of Set 11 | puli
# Processing Record 17 of Set 11 | marsaxlokk
# Processing Record 18 of Set 11 | nakamura
# Processing Record 19 of Set 11 | bulgan
# Processing Record 20 of Set 11 | rio gallegos
# Processing Record 21 of Set 11 | vestmanna
# Processing Record 22 of Set 11 | los llanos de aridane
# Processing Record 23 of Set 11 | natal
# Processing Record 24 of Set 11 | sale
# Processing Record 25 of Set 11 | nassau
# Processing Record 26 of Set 11 | ambilobe
# Processing Record 27 of Set 11 | biak
# Processing Record 28 of Set 11 | walsrode
# Processing Record 29 of Set 11 | toamasina
# Processing Record 30 of Set 11 | luquillo
# Processing Record 31 of Set 11 | dalby
# Processing Record 32 of Set 11 | cape canaveral
# Processing Record 33 of Set 11 | shambu
# Processing Record 34 of Set 11 | ilulissat
# Processing Record 35 of Set 11 | kashi
# Processing Record 36 of Set 11 | aripuana
# Processing Record 37 of Set 11 | merauke
# Processing Record 38 of Set 11 | lahaina
# Processing Record 39 of Set 11 | aklavik
# Processing Record 40 of Set 11 | chumikan
# Processing Record 41 of Set 11 | sayyan
# Processing Record 42 of Set 11 | stoyba
# City not found. Skipping...
# Processing Record 43 of Set 11 | beatrice
# Processing Record 44 of Set 11 | makakilo city
# Processing Record 45 of Set 11 | komsomolskiy
# Processing Record 46 of Set 11 | nizhniy kuranakh
# Processing Record 47 of Set 11 | vallenar
# Processing Record 48 of Set 11 | utiel
# Processing Record 49 of Set 11 | kuytun
# Processing Record 50 of Set 11 | pimentel
# Processing Record 1 of Set 12 | tres arroyos
# Processing Record 2 of Set 12 | batagay-alyta
# Processing Record 3 of Set 12 | kongolo
# Processing Record 4 of Set 12 | sabha
# Processing Record 5 of Set 12 | port hardy
# Processing Record 6 of Set 12 | hihifo
# City not found. Skipping...
# Processing Record 7 of Set 12 | gladstone
# Processing Record 8 of Set 12 | svetlaya
# Processing Record 9 of Set 12 | krasnyy yar
# Processing Record 10 of Set 12 | dzerzhinskoye
# Processing Record 11 of Set 12 | masuguru
# Processing Record 12 of Set 12 | negele
# City not found. Skipping...
# Processing Record 13 of Set 12 | kenai
# Processing Record 14 of Set 12 | dalbandin
# Processing Record 15 of Set 12 | yatou
# Processing Record 16 of Set 12 | tazovskiy
# Processing Record 17 of Set 12 | tamandare
# Processing Record 18 of Set 12 | manggar
# Processing Record 19 of Set 12 | honningsvag
# Processing Record 20 of Set 12 | truth or consequences
# Processing Record 21 of Set 12 | uvat
# Processing Record 22 of Set 12 | bandarbeyla
# Processing Record 23 of Set 12 | tigil
# Processing Record 24 of Set 12 | belaya gora
# Processing Record 25 of Set 12 | ibra
# Processing Record 26 of Set 12 | vao
# Processing Record 27 of Set 12 | seka
# Processing Record 28 of Set 12 | broome
# Processing Record 29 of Set 12 | vila velha
# Processing Record 30 of Set 12 | santo antonio do ica
# Processing Record 31 of Set 12 | roald
# Processing Record 32 of Set 12 | mareeba
# Processing Record 33 of Set 12 | quatre cocos
# Processing Record 34 of Set 12 | granja
# Processing Record 35 of Set 12 | puerto leguizamo
# Processing Record 36 of Set 12 | cidreira
# Processing Record 37 of Set 12 | vangaindrano
# Processing Record 38 of Set 12 | smolenka
# Processing Record 39 of Set 12 | rapid valley
# Processing Record 40 of Set 12 | jhargram
# Processing Record 41 of Set 12 | hervey bay
# Processing Record 42 of Set 12 | lithgow
# Processing Record 43 of Set 12 | whitianga
# Processing Record 44 of Set 12 | rawannawi
# City not found. Skipping...
# Processing Record 45 of Set 12 | ardakan
# Processing Record 46 of Set 12 | karakendzha
# City not found. Skipping...
# Processing Record 47 of Set 12 | mosquera
# Processing Record 48 of Set 12 | ternate
# Processing Record 49 of Set 12 | hagenow
# Processing Record 50 of Set 12 | goderich
# Processing Record 1 of Set 13 | beni suef
# Processing Record 2 of Set 13 | ugoofaaru
# Processing Record 3 of Set 13 | bondo
# Processing Record 4 of Set 13 | narsaq
# Processing Record 5 of Set 13 | gat
# Processing Record 6 of Set 13 | port macquarie
# Processing Record 7 of Set 13 | biskamzha
# Processing Record 8 of Set 13 | bacolod
# Processing Record 9 of Set 13 | fuerte olimpo
# Processing Record 10 of Set 13 | moron
# Processing Record 11 of Set 13 | bucak
# Processing Record 12 of Set 13 | muchkapskiy
# Processing Record 13 of Set 13 | loukhi
# Processing Record 14 of Set 13 | izhma
# Processing Record 15 of Set 13 | colares
# Processing Record 16 of Set 13 | keflavik
# Processing Record 17 of Set 13 | jumla
# Processing Record 18 of Set 13 | hovd
# Processing Record 19 of Set 13 | kautokeino
# Processing Record 20 of Set 13 | buriti alegre
# Processing Record 21 of Set 13 | tocopilla
# Processing Record 22 of Set 13 | ussel
# Processing Record 23 of Set 13 | nuuk
# Processing Record 24 of Set 13 | ruatoria
# City not found. Skipping...
# Processing Record 25 of Set 13 | tacoaleche
# Processing Record 26 of Set 13 | juneau
# Processing Record 27 of Set 13 | brigantine
# Processing Record 28 of Set 13 | luganville
# Processing Record 29 of Set 13 | pitanga
# Processing Record 30 of Set 13 | payson
# Processing Record 31 of Set 13 | jaru
# Processing Record 32 of Set 13 | san quintin
# Processing Record 33 of Set 13 | barcelos
# Processing Record 34 of Set 13 | yarada
# Processing Record 35 of Set 13 | yeniseysk
# Processing Record 36 of Set 13 | bubaque
# Processing Record 37 of Set 13 | margate
# Processing Record 38 of Set 13 | talara
# Processing Record 39 of Set 13 | wheeling
# Processing Record 40 of Set 13 | emet
# Processing Record 41 of Set 13 | ostrowiec swietokrzyski
# Processing Record 42 of Set 13 | hun
# Processing Record 43 of Set 13 | inhambane
# Processing Record 44 of Set 13 | caapucu
# Processing Record 45 of Set 13 | san vito
# Processing Record 46 of Set 13 | logan
# Processing Record 47 of Set 13 | melilla
# Processing Record 48 of Set 13 | paradwip
# City not found. Skipping...
# Processing Record 49 of Set 13 | qaqortoq
# Processing Record 50 of Set 13 | goundam
# Processing Record 1 of Set 14 | lloydminster
# Processing Record 2 of Set 14 | corner brook
# Processing Record 3 of Set 14 | tunceli
# Processing Record 4 of Set 14 | ramnagar
# Processing Record 5 of Set 14 | nalut
# Processing Record 6 of Set 14 | muriti
# Processing Record 7 of Set 14 | alvaraes
# Processing Record 8 of Set 14 | ushtobe
# Processing Record 9 of Set 14 | bras-panon
# Processing Record 10 of Set 14 | zhigalovo
# Processing Record 11 of Set 14 | amboasary
# Processing Record 12 of Set 14 | okhotsk
# Processing Record 13 of Set 14 | alekseyevsk
# Processing Record 14 of Set 14 | tura
# Processing Record 15 of Set 14 | san vicente
# Processing Record 16 of Set 14 | mendi
# Processing Record 17 of Set 14 | morros
# Processing Record 18 of Set 14 | lannion
# Processing Record 19 of Set 14 | dire
# Processing Record 20 of Set 14 | pousat
# City not found. Skipping...
# Processing Record 21 of Set 14 | waingapu
# Processing Record 22 of Set 14 | nioro
# Processing Record 23 of Set 14 | umm lajj
# Processing Record 24 of Set 14 | kutum
# Processing Record 25 of Set 14 | aksu
# Processing Record 26 of Set 14 | knysna
# Processing Record 27 of Set 14 | of
# City not found. Skipping...
# Processing Record 28 of Set 14 | igrim
# Processing Record 29 of Set 14 | olean
# Processing Record 30 of Set 14 | mingguang
# Processing Record 31 of Set 14 | kabalo
# Processing Record 32 of Set 14 | george town
# Processing Record 33 of Set 14 | sambava
# Processing Record 34 of Set 14 | clarence town
# Processing Record 35 of Set 14 | acin
# City not found. Skipping...
# Processing Record 36 of Set 14 | piro
# Processing Record 37 of Set 14 | carndonagh
# Processing Record 38 of Set 14 | bhindar
# Processing Record 39 of Set 14 | oranjemund
# Processing Record 40 of Set 14 | great falls
# Processing Record 41 of Set 14 | hoi an
# Processing Record 42 of Set 14 | mumford
# Processing Record 43 of Set 14 | panuco
# Processing Record 44 of Set 14 | lechinta
# Processing Record 45 of Set 14 | warmbad
# Processing Record 46 of Set 14 | lai
# Processing Record 47 of Set 14 | lakatoro
# Processing Record 48 of Set 14 | dhanera
# Processing Record 49 of Set 14 | la tuque
# Processing Record 50 of Set 14 | port augusta
# Processing Record 1 of Set 15 | garissa
# Processing Record 2 of Set 15 | ustyuzhna
# Processing Record 3 of Set 15 | pandaria
# Processing Record 4 of Set 15 | sept-iles
# Processing Record 5 of Set 15 | muyezerskiy
# Processing Record 6 of Set 15 | xining
# Processing Record 7 of Set 15 | emerald
# Processing Record 8 of Set 15 | abu zabad
# Processing Record 9 of Set 15 | akyab
# Processing Record 10 of Set 15 | pattani
# Processing Record 11 of Set 15 | broken hill
# Processing Record 12 of Set 15 | aktash
# Processing Record 13 of Set 15 | moyobamba
# Processing Record 14 of Set 15 | lakes entrance
# Processing Record 15 of Set 15 | road town
# Processing Record 16 of Set 15 | beloha
# Processing Record 17 of Set 15 | lusambo
# Processing Record 18 of Set 15 | mangaratiba
# Processing Record 19 of Set 15 | linjiang
# Processing Record 20 of Set 15 | cody
# Processing Record 21 of Set 15 | puebloviejo
# Processing Record 22 of Set 15 | greeley
# Processing Record 23 of Set 15 | naberera
# Processing Record 24 of Set 15 | tabiauea
# City not found. Skipping...
# Processing Record 25 of Set 15 | kingaroy
# Processing Record 26 of Set 15 | havelock
# Processing Record 27 of Set 15 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 28 of Set 15 | santa maria
# Processing Record 29 of Set 15 | porto torres
# Processing Record 30 of Set 15 | georgiyevka
# Processing Record 31 of Set 15 | kawalu
# Processing Record 32 of Set 15 | sungai besar
# Processing Record 33 of Set 15 | skerries
# Processing Record 34 of Set 15 | tambopata
# Processing Record 35 of Set 15 | pangody
# Processing Record 36 of Set 15 | nichinan
# Processing Record 37 of Set 15 | dalvik
# Processing Record 38 of Set 15 | zhigansk
# Processing Record 39 of Set 15 | urshelskiy
# Processing Record 40 of Set 15 | bati
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Kralendijk      BQ  12.1500  -68.2667     76.98        83          29
# 1         Buchanan      LR   5.8808  -10.0467     77.05        88          89
# 2            Bluff      NZ -46.6000  168.3333     60.80        67           0
# 3            Kapaa      US  22.0752 -159.3190     78.78        77          40
# 4  Haines Junction      CA  60.7522 -137.5108     37.35        56          43
#
#    Wind Speed Current Description
# 0        9.22    scattered clouds
# 1        5.08          light rain
# 2       13.67           clear sky
# 3       12.66    scattered clouds
# 4       13.80    scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
